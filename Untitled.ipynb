# %%
import pandas as pd

# %%
filename = "C:/Users/gibbn/Documents/meteohack-2019/data/010_room_air_conditioners_climatiseurs_individuels/010_Data_Données.csv"
pd.read_csv(filename, encoding='cp1252')
# Out:
#       REC_REF_KEY        MODEL_NUM_1                          BRAND_NAME  \
# 0          191442            SCA09LS                            Wallmate
# 1          220965           13-04514                                Gree
# 2          827371           13-04596                           ForestAir
# 3          827372           13-04597                           ForestAir
# 4          827376           13-04547                             Fellini
# 5          827378           13-04531                             Fellini
# 6         1402316           13-04593                           ForestAir
# 7         1664681           13-04588                           ForestAir
# 8         1664683           13-04590                           ForestAir
# 9         1664684           13-04591                           ForestAir
# 10        1664685           13-04592                           ForestAir
# 11        1664686           13-04594                           ForestAir
# ...
