# %%
import pandas as pd

# %%
filename = "data/010_room_air_conditioners_climatiseurs_individuels/010_Data_Données.csv"
acs = pd.read_csv(filename, encoding='cp1252')

# %%
acs.head()
# Out:
#    REC_REF_KEY MODEL_NUM_1 BRAND_NAME  EE_RATIO  COOL_CAP_KW  COOL_CAP_BTU  \
# 0       191442     SCA09LS   Wallmate       8.7        2.723          9300
# 1       220965    13-04514       Gree       9.7        1.523          5200
# 2       827371    13-04596  ForestAir      10.5        2.401          8200
# 3       827372    13-04597  ForestAir       9.8        2.928         10000
# 4       827376    13-04547    Fellini      10.7        1.757          6000
#
#   PROD_CLASS_LABEL_EN           PROD_CLASS_LABEL_FR  \
# 0        non-louvered  appareils à évents sans lame
# 1            louvered       appareils à évents lame
# 2            louvered       appareils à évents lame
# 3            louvered       appareils à évents lame
# 4            louvered       appareils à évents lame
#
#             HEAT_ELEMENT_LABEL_EN                      HEAT_ELEMENT_LABEL_FR  \
# 0    no electric heating elements     sans éléments électriques de chauffage
# 1    no electric heating elements     sans éléments électriques de chauffage
# 2    no electric heating elements     sans éléments électriques de chauffage
# 3    no electric heating elements     sans éléments électriques de chauffage
# 4  with electric heating elements  dotée d'éléments électriques de chauffage
#
#    VOLTAGE_LABEL_EN  VOLTAGE_LABEL_FR                 ENERGUIDE_LABEL_EN  \
# 0               120               120  non-louvred without reverse cycle
# 1               120               120      louvred without reverse cycle
# 2               120               120      louvred without reverse cycle
# 3               120               120      louvred without reverse cycle
# 4               120               120      louvred without reverse cycle
#
#                     ENERGUIDE_LABEL_FR  REVERSE_CYCLES_LABEL_EN  \
# 0  sans lames et sans cycle réversible  without a reverse cycle
# 1     à lames et sans cycle réversible  without a reverse cycle
# 2     à lames et sans cycle réversible  without a reverse cycle
# 3     à lames et sans cycle réversible  without a reverse cycle
# 4     à lames et sans cycle réversible  without a reverse cycle
#
#   REVERSE_CYCLES_LABEL_FR  AMPS
# 0   sans cycle réversible  10.0
# 1   sans cycle réversible   4.7
# 2   sans cycle réversible   5.2
# 3   sans cycle réversible   9.5
# 4   sans cycle réversible   4.9

# %%
acs["BRAND_NAME"].unique().tolist()
# Out:
# ['Wallmate',
#  'Gree',
#  'ForestAir',
#  'Fellini',
#  'Commercial Cool',
#  'Danby',
#  'Friedrich',
#  'Amana Heating and Air Conditioning',
#  'Haier',
#  'Comfort-Aire',
#  'Manuflow',
#  'Garrison',
#  'Koolking',
#  'Uberhaus',
#  'GE',
#  'Royal Sovereign',
#  'Arctic Aire',
#  'LG',
#  'Mainstays',
#  'Frigidaire',
#  'Coolworks',
#  'Midea',
#  'Perfect Comfort',
#  'Quirky',
#  'Comfee',
#  'True Possession',
#  'Perfect Aire',
#  'Arctic King',
#  'Noma',
#  'Kenmore']
